# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# 2. Pad sequences
maxlen = 250
train_data = pad_sequences(train_data, maxlen=maxlen)
test_data = pad_sequences(test_data, maxlen=maxlen)

# %%
print("Train shape:", train_data.shape)
print("Test shape:", test_data.shape)
# Out:
# Train shape: (25000, 250)
# Test shape: (25000, 250)

# %%
# 3. Build Sequential Model
model = keras.Sequential([
    layers.Embedding(input_dim=10000, output_dim=32, input_length=maxlen),
    layers.LSTM(32),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# 4. Compile model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# 5. Summary
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# 6. Train model
history = model.fit(
    train_data,
    train_labels,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 26s 148ms/step - accuracy: 0.7291 - loss: 0.5291 - val_accuracy: 0.8416 - val_loss: 0.3693
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 39s 135ms/step - accuracy: 0.8864 - loss: 0.2919 - val_accuracy: 0.8592 - val_loss: 0.3281
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 144ms/step - accuracy: 0.9221 - loss: 0.2133 - val_accuracy: 0.8714 - val_loss: 0.3126
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 22s 138ms/step - accuracy: 0.9370 - loss: 0.1793 - val_accuracy: 0.8686 - val_loss: 0.3896
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 145ms/step - accuracy: 0.9526 - loss: 0.1420 - val_accuracy: 0.8664 - val_loss: 0.3436
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 150ms/step - accuracy: 0.9679 - loss: 0.1031 - val_accuracy: 0.8686 - val_loss: 0.4404
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 23s 145ms/step - accuracy: 0.9718 - loss: 0.0942 - val_accuracy: 0.8712 - val_loss: 0.4643
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 40s 138ms/step - accuracy: 0.9714 - loss: 0.0886 - val_accuracy: 0.8618 - val_loss: 0.4251
# Epoch 9/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 42s 146ms/step - accuracy: 0.9811 - loss: 0.0648 - val_accuracy: 0.8596 - val_loss: 0.4775
# Epoch 10/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 41s 146ms/step - accuracy: 0.9783 - loss: 0.0702 - val_accuracy: 0.8642 - val_loss: 0.5200

# %%
# 7. Evaluate model
loss, accuracy = model.evaluate(test_data, test_labels)

print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 18s 23ms/step - accuracy: 0.8500 - loss: 0.5818
# Test Loss: 0.5817897319793701
# Test Accuracy: 0.8500400185585022
